# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the csv into a dataframe
df = pd.read_csv('/home/stephen/Week4_Assignment/outcome-of-care-measures.csv')

# %%
# Set the plot dimensions
fig_dims = (10, 7)

# Create the 'fig' & 'ax' attributes
fig, ax = plt.subplots(figsize=fig_dims)

# Create the histogram
sns.set_style('darkgrid')
sns.histplot(df['Hospital 30-Day Death (Mortality) Rates from Heart Attack'], 
             bins='auto', ax=ax)
# Out:
# <AxesSubplot:xlabel='Hospital 30-Day Death (Mortality) Rates from Heart Attack', ylabel='Count'>
